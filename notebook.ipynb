# %%
import pandas as pd
df = pd.read_excel('data.xlsx', index_col=0)
df.head()
# Out:
#      Артикул                                    Ссылка на товар  \
# 0  488386749  https://www.wildberries.ru/catalog/488386749/d...
# 1  239833866  https://www.wildberries.ru/catalog/239833866/d...
# 2  203138526  https://www.wildberries.ru/catalog/203138526/d...
# 3  488387894  https://www.wildberries.ru/catalog/488387894/d...
# 4  287700029  https://www.wildberries.ru/catalog/287700029/d...
#
#                                             Название  Рейтинг  \
# 0      Пальто длинное оверсайз весна-осень в полоску      4.9
# 1  Пальто шерстяное демисезонное с воротником сто...      4.9
# 2                                    Пальто классика      4.8
# 3                 Пальто весна-осень макси в полоску      4.8
# 4                       Пальто шерстяное натуральное      4.8
#
#    Количество отзывов                                            Размеры  \
# 0                 120                                        42,44,46,48
# ...

# %%
target = df.query("`Страна производства` == 'Россия' and `Рейтинг` >= 4.5 and `Цена` < 10000")
target.to_excel("filtered.xlsx")
target.head()
# Out:
#       Артикул                                    Ссылка на товар  \
# 1   239833866  https://www.wildberries.ru/catalog/239833866/d...
# 14  288989036  https://www.wildberries.ru/catalog/288989036/d...
# 15  366417625  https://www.wildberries.ru/catalog/366417625/d...
# 16  277883751  https://www.wildberries.ru/catalog/277883751/d...
# 17  287694148  https://www.wildberries.ru/catalog/287694148/d...
#
#                                              Название  Рейтинг  \
# 1   Пальто шерстяное демисезонное с воротником сто...      4.9
# 14                          Короткое шерстяное пальто      4.6
# 15                          Короткое шерстяное пальто      4.9
# 16                               Полупальто шерстяное      4.7
# 17                               Полупальто шерстяное      4.9
#
#     Количество отзывов               Размеры  Цена  \
# 1                 1845  42,44,46,48,50,52,54  8278
# 14                  55     42,44,46,48,50,52  8417
# ...
